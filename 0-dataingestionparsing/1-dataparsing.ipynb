# %%
import langchain
from typing import Dict, List, Any
import pandas as pd

# %%
from langchain_core.documents import Document
from langchain_text_splitters import (
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    TokenTextSplitter
)

print("Import worked!")
# Out:
# Import worked!

# %%
doc = Document(
    page_content = "",
    metadata= {
        "source":"udemy course",
        "page":1,
        "author":"unknown",
        "created_by":"12/5/2025"
    }
)

# %%
print(f"Here's page content {doc.page_content}")
print(f"Here's page metadata {doc.metadata}")


print("Meta is useful for follwing, like filter the content by author  and tracing the source name, document data")

type(doc)
# Out:
# Here's page content
# Here's page metadata {'source': 'udemy course', 'page': 1, 'author': 'unknown', 'created_by': '12/5/2025'}
# Meta is useful for follwing, like filter the content by author  and tracing the source name, document data
# langchain_core.documents.base.Document
